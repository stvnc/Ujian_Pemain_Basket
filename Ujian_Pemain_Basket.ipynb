# %% [markdown]
# # Ujian Pemain Basket
# ## Exam Modul 03
# ### Name : Vincent Angelo
# ### Date : 10 Feb 2020

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
nbaDf = pd.read_csv('all_seasons.csv')
nbaDf.head()
# Out:
#    Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 0           0   Chris Robinson               VAN  23.0         195.58
# 1           1        Matt Fish               MIA  27.0         210.82
# 2           2     Matt Bullard               HOU  30.0         208.28
# 3           3     Marty Conlon               BOS  29.0         210.82
# 4           4  Martin Muursepp               DAL  22.0         205.74
#
#    player_weight                    college country draft_year draft_round  \
# 0       90.71840           Western Kentucky     USA       1996           2
# 1      106.59412  North Carolina-Wilmington     USA       1992           2
# 2      106.59412                       Iowa     USA  Undrafted   Undrafted
# 3      111.13004                 Providence     USA  Undrafted   Undrafted
# 4      106.59412                       None     USA       1996           1
#
#    ...  pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# ...

# %%
targetDf = nbaDf[(nbaDf['age'] <= 25) & (nbaDf['player_height'] >= 180) & (nbaDf['player_weight'] <= 90) 
                & (nbaDf['pts'] >= 6) & (nbaDf['reb'] >= 3)]
targetDf.index.values
# Out:
# array([ 105,  290,  432,  659,  835,  874, 1018, 1032, 1062, 1135, 1141,
#        1332, 1351, 1436, 1515, 1516, 1720, 1727, 1748, 1951, 2004, 2018,
#        2047, 2101, 2114, 2143, 2203, 2259, 2394, 2398, 2484, 2544, 2551,
#        2631, 2704, 2836, 2840, 2873, 2984, 3010, 3081, 3159, 3329, 3376,
#        3389, 3441, 3449, 3529, 3558, 3573, 3704, 3717, 3721, 3830, 3994,
#        4036, 4039, 4121, 4124, 4252, 4267, 4271, 4374, 4385, 4422, 4482,
#        4483, 4502, 4528, 4547, 4556, 4613, 4624, 4633, 4665, 4775, 4800,
#        4924, 5070, 5154, 5156, 5164, 5229, 5274, 5292, 5293, 5383, 5390,
#        5512, 5521, 5522, 5548, 5587, 5609, 5675, 5743, 5747, 5820, 5914,
#        5952, 6001, 6014, 6040, 6098, 6183, 6272, 6277, 6304, 6343, 6360,
#        6408, 6409, 6441, 6450, 6542, 6639, 6710, 6810, 6822, 6871, 6926,
#        6959, 6979, 7009, 7040, 7059, 7073, 7091, 7184, 7199, 7305, 7306,
#        7342, 7365, 7369, 7389, 7491, 7521, 7601, 7643, 7654, 7655, 7720,
# ...

# %%
targetList = []
targetIndex = targetDf.index.values

for i in range(len(nbaDf)):
    if i in targetIndex:
        targetList.append(1)
    else:
        targetList.append(0)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split as tts
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %%
def findScore(model, paramXTrain, paramYTrain, paramXTest, paramYTest):
    model.fit(paramXTrain, paramYTrain)
    yPred = model.predict(paramXTest)
    print("Model: ", model)
    print("Best Parameters: ", model.best_params_)
    print("Accuracy Score: ", accuracy_score(paramYTest, yPred))
    print("Precision Score: ", precision_score(paramYTest, yPred))
    print("Recall: ", recall_score(paramYTest, yPred))
    print("F1 Score: ", f1_score(paramYTest, yPred))
    print("ROC AUC Score: ", roc_auc_score(paramYTest, yPred))
    print("First 10 Prediction: ", yPred[:10])
    print("First 10 Actual: ", paramYTest[:10])
    print("")

# %%
scoutData = pd.DataFrame({
    'Name': ['Andakara Prastawa Dyaksa', 'Reggie Mononimbar', 'Hardianus Lakudu', 
             'Kevin Yonas Sitorus', 'Arki Dikania Wisnu', 'Laurentius Steven Oei', 'Mei Joni', 
             'Vincent Rivaldi Kosasih', 'Hardian Wicaksono', 'Brandon Jawato'],
    'Club': ['Pelita Jaya Bakrie', 'Pelita Jaya Bakrie', 'Satria Muda Pertamina Jakarta', 
             'Satria Muda Pertamina Jakarta', 'Satria Muda Pertamina Jakarta', 'Satria Muda Pertamina Jakarta',
             'Stapac', 'Stapac', 'Pacific Caesar Surabaya', 'Louvre Surabaya'],
    'Country': ['Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia', 'Indonesia'],
    'Age': [24, 21, 23, 26, 20, 21, 25, 23, 21, 24],
    'Height': [190, 185, 178, 185, 183, 191, 188, 179, 177, 182],
    'Weight': [90, 86, 83, 75, 80, 85, 90, 87, 80, 85],
    'Avg Points': [7, 6, 10, 11, 5, 4, 7, 1, 9, 6],
    'Avg Rebounds': [6, 3, 3, 4, 2, 10, 5, 2, 8, 5]
})

scoutData
# Out:
#                        Name                           Club    Country  Age  \
# 0  Andakara Prastawa Dyaksa             Pelita Jaya Bakrie  Indonesia   24
# 1         Reggie Mononimbar             Pelita Jaya Bakrie  Indonesia   21
# 2          Hardianus Lakudu  Satria Muda Pertamina Jakarta  Indonesia   23
# 3       Kevin Yonas Sitorus  Satria Muda Pertamina Jakarta  Indonesia   26
# 4        Arki Dikania Wisnu  Satria Muda Pertamina Jakarta  Indonesia   20
# 5     Laurentius Steven Oei  Satria Muda Pertamina Jakarta  Indonesia   21
# 6                  Mei Joni                         Stapac  Indonesia   25
# 7   Vincent Rivaldi Kosasih                         Stapac  Indonesia   23
# 8         Hardian Wicaksono        Pacific Caesar Surabaya  Indonesia   21
# 9            Brandon Jawato                Louvre Surabaya  Indonesia   24
#
#    Height  Weight  Avg Points  Avg Rebounds
# 0     190      90           7             6
# 1     185      86           6             3
# ...

# %% [markdown]
# ### Without Standardization

# %%
dataToUse = nbaDf[['age', 'player_height', 'player_weight', 'pts', 'reb']]

x = np.array(dataToUse)
y = np.array(targetList)

# %%
xtr, xts, ytr, yts = tts(x, y, test_size = .18)

# %% [markdown]
# #### Hyperparameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV as RSCV

# %%
k = round(xtr.shape[0] ** .5)
if k % 2 == 0:
    k+=1
    
n_neighbors = list(range(k-5, k+5))
algo = ["ball_tree", "kd_tree", "brute", "auto"]

paramKNN = {
    "n_neighbors": n_neighbors,
    "algorithm": algo
}
paramKNN

knn = KNN()
modelKNN = RSCV(estimator= knn, 
                             param_distributions= paramKNN, 
                             cv= 5)

# %%
penalty = ["l1", "l2", "elasticnet", "none"]
solver = ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
max_iter = [1, 10, 100, 1000, 10000]

paramLore = {
    "penalty": penalty,
    "solver": solver,
    "max_iter" : max_iter
}
paramLore

lore = LogisticRegression()
modelLore = RSCV(estimator= lore, 
                             param_distributions= paramLore, 
                             cv= 5)

# %%
n_estimators = list(range(10, 100, 5))
max_features = ['auto', 'sqrt']
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

paramRFC = {'n_estimators': n_estimators,
               'max_features': max_features,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rfc = RFC()
modelRFC = RSCV(estimator= rfc, 
                             param_distributions= paramRFC, 
                             cv= 5)

# %%
models = [modelKNN, modelLore, modelRFC]

for i in models:
    findScore(i, xtr, ytr, xts, yts)
# Out:
# Model:  RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=KNeighborsClassifier(algorithm='auto',
#                                                   leaf_size=30,
#                                                   metric='minkowski',
#                                                   metric_params=None,
#                                                   n_jobs=None, n_neighbors=5,
#                                                   p=2, weights='uniform'),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'algorithm': ['ball_tree', 'kd_tree',
#                                                       'brute', 'auto'],
#                                         'n_neighbors': [84, 85, 86, 87, 88, 89,
#                                                         90, 91, 92, 93]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
# ...

# %% [markdown]
# ### Menggunakan RandomForest Classifier dengan overall average score tertinggi

# %%
usableData = scoutData[['Age', 'Height', 'Weight', 'Avg Points', 'Avg Rebounds']]
usableData
# Out:
#    Age  Height  Weight  Avg Points  Avg Rebounds
# 0   24     190      90           7             6
# 1   21     185      86           6             3
# 2   23     178      83          10             3
# 3   26     185      75          11             4
# 4   20     183      80           5             2
# 5   21     191      85           4            10
# 6   25     188      90           7             5
# 7   23     179      87           1             2
# 8   21     177      80           9             8
# 9   24     182      85           6             5

# %%
scoutData['RFC'] = modelRFC.predict(usableData)
scoutData
# Out:
#                        Name                           Club    Country  Age  \
# 0  Andakara Prastawa Dyaksa             Pelita Jaya Bakrie  Indonesia   24
# 1         Reggie Mononimbar             Pelita Jaya Bakrie  Indonesia   21
# 2          Hardianus Lakudu  Satria Muda Pertamina Jakarta  Indonesia   23
# 3       Kevin Yonas Sitorus  Satria Muda Pertamina Jakarta  Indonesia   26
# 4        Arki Dikania Wisnu  Satria Muda Pertamina Jakarta  Indonesia   20
# 5     Laurentius Steven Oei  Satria Muda Pertamina Jakarta  Indonesia   21
# 6                  Mei Joni                         Stapac  Indonesia   25
# 7   Vincent Rivaldi Kosasih                         Stapac  Indonesia   23
# 8         Hardian Wicaksono        Pacific Caesar Surabaya  Indonesia   21
# 9            Brandon Jawato                Louvre Surabaya  Indonesia   24
#
#    Height  Weight  Avg Points  Avg Rebounds  RFC
# 0     190      90           7             6    1
# ...

# %%
scoutData[scoutData['RFC'] == 1]
# Out:
#                        Name                Club    Country  Age  Height  \
# 0  Andakara Prastawa Dyaksa  Pelita Jaya Bakrie  Indonesia   24     190
# 1         Reggie Mononimbar  Pelita Jaya Bakrie  Indonesia   21     185
# 6                  Mei Joni              Stapac  Indonesia   25     188
# 9            Brandon Jawato     Louvre Surabaya  Indonesia   24     182
#
#    Weight  Avg Points  Avg Rebounds  RFC
# 0      90           7             6    1
# 1      86           6             3    1
# 6      90           7             5    1
# 9      85           6             5    1

# %% [markdown]
# ### With Standardization

# %%
dataToUse = nbaDf[['age', 'player_height', 'player_weight', 'pts', 'reb']]
ss = StandardScaler()
standardizedData = ss.fit_transform(dataToUse)

x = np.array(standardizedData)
y = np.array(targetList)

# %%
xtr, xts, ytr, yts = tts(x, y, test_size = .18)

# %%
k = round(xtr.shape[0] ** .5)
if k % 2 == 0:
    k+=1
    
n_neighbors = list(range(k-5, k+5))
algo = ["ball_tree", "kd_tree", "brute", "auto"]

paramKNN = {
    "n_neighbors": n_neighbors,
    "algorithm": algo
}
paramKNN

knn = KNN()
modelKNN = RSCV(estimator= knn, 
                             param_distributions= paramKNN, 
                             cv= 5)

# %%
penalty = ["l1", "l2", "elasticnet", "none"]
solver = ["newton-cg", "lbfgs", "liblinear", "sag", "saga"]
max_iter = [1, 10, 100, 1000, 10000]

paramLore = {
    "penalty": penalty,
    "solver": solver,
    "max_iter" : max_iter
}
paramLore

lore = LogisticRegression()
modelLore = RSCV(estimator= lore, 
                             param_distributions= paramLore, 
                             cv= 5)

# %%
n_estimators = list(range(10, 100, 5))
max_features = ['auto', 'sqrt']
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

paramRFC = {'n_estimators': n_estimators,
               'max_features': max_features,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rfc = RFC()
modelRFC = RSCV(estimator= rfc, 
                             param_distributions= paramRFC, 
                             cv= 5)

# %%
models = [modelKNN, modelLore, modelRFC]

for i in models:
    findScore(i, xtr, ytr, xts, yts)
# Out:
# Model:  RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=KNeighborsClassifier(algorithm='auto',
#                                                   leaf_size=30,
#                                                   metric='minkowski',
#                                                   metric_params=None,
#                                                   n_jobs=None, n_neighbors=5,
#                                                   p=2, weights='uniform'),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'algorithm': ['ball_tree', 'kd_tree',
#                                                       'brute', 'auto'],
#                                         'n_neighbors': [84, 85, 86, 87, 88, 89,
#                                                         90, 91, 92, 93]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
# ...

# %% [markdown]
# ### Menggunakan RandomForest Classifier dengan overall average score tertinggi

# %%
modelRFC.fit(xtr, ytr)
standardizedData = ss.fit_transform(usableData)
scoutData['RFC'] = modelRFC.predict(standardizedData)
scoutData
# Out:
#                        Name                           Club    Country  Age  \
# 0  Andakara Prastawa Dyaksa             Pelita Jaya Bakrie  Indonesia   24
# 1         Reggie Mononimbar             Pelita Jaya Bakrie  Indonesia   21
# 2          Hardianus Lakudu  Satria Muda Pertamina Jakarta  Indonesia   23
# 3       Kevin Yonas Sitorus  Satria Muda Pertamina Jakarta  Indonesia   26
# 4        Arki Dikania Wisnu  Satria Muda Pertamina Jakarta  Indonesia   20
# 5     Laurentius Steven Oei  Satria Muda Pertamina Jakarta  Indonesia   21
# 6                  Mei Joni                         Stapac  Indonesia   25
# 7   Vincent Rivaldi Kosasih                         Stapac  Indonesia   23
# 8         Hardian Wicaksono        Pacific Caesar Surabaya  Indonesia   21
# 9            Brandon Jawato                Louvre Surabaya  Indonesia   24
#
#    Height  Weight  Avg Points  Avg Rebounds  RFC
# 0     190      90           7             6    0
# ...

# %%
scoutData[scoutData['RFC'] == 1]
# Out:
#                 Name                     Club    Country  Age  Height  Weight  \
# 8  Hardian Wicaksono  Pacific Caesar Surabaya  Indonesia   21     177      80
#
#    Avg Points  Avg Rebounds  RFC
# 8           9             8    1

# %% [markdown]
# ### Setelah data distandardisasi,ada 1 pemain yang cocok untuk direkrut. Berbeda dengan data sebelum distandardisasi, yang menghasilkan 4 pemain yang layak untuk direkrut.
